# %% [markdown]
# Declare your age as integer variable

# %%
age = int(29)

# %% [markdown]
# Declare your height as a float variable

# %%
height = float(172)

# %% [markdown]
# Declare a variable that store a complex number

# %%
complex_number = 4 + 5j
print(complex_number)
# Out:
# (4+5j)

# %% [markdown]
# Write a script that prompts the user to enter base and height of the triangle and calculate an area of this triangle (area = 0.5 x b x h).
#     Enter base: 20
#     Enter height: 10
#     The area of the triangle is 100

# %%
base = float(input("digite Base del triangulo"))
height = float(input("digite Altura del triangulo"))
print(f"El area del triangulo es : {0.5 * base * height}")
# Out:
# El area del triangulo es : 138.0

# %% [markdown]
# Write a script that prompts the user to enter side a, side b, and side c of the triangle. Calculate the perimeter of the triangle (perimeter = a + b + c).
# Enter side a: 5
# Enter side b: 4
# Enter side c: 3
# The perimeter of the triangle is 12

# %%
print("Calculo del perimetro de Triangulo")
side_a= float(input("Enter Side a : "))
side_b= float(input("Enter Side b : "))
side_c= float(input("Enter Side c : "))
print(f"The perimeter of the triangle is : {side_a + side_b +side_c}")
# Out:
# Calculo del perimetro de Triangulo
# The perimeter of the triangle is : 12.0

# %% [markdown]
# Get length and width of a rectangle using prompt. Calculate its area (area = length x width) and perimeter (perimeter = 2 x (length + width))

# %%
import math
length = float(input("digite longitud de rectangulo : "))
width = float(input("digite ancho de rectangulo : "))
print(f"el area del rectangulo es {length * width} ")
print(f"el perimetro del rectangulo es { 2 * (length + width)} ")
# Out:
# el area del rectangulo es 20.0
# el perimetro del rectangulo es 18.0

# %% [markdown]
# Get radius of a circle using prompt. Calculate the area (area = pi x r x r) and circumference (c = 2 x pi x r) where pi = 3.14.

# %%
import math
radius = float(input("digite radio del circulo : "))
print(f"el area del circulo  es {math.pi * radius * radius} ")
print(f"la circuferencia del circulo  es {math.pi * 2 * radius} ")
# Out:
# el area del circulo  es 28.274333882308138
# la circuferencia del circulo  es 18.84955592153876

# %% [markdown]
# Calculate the slope, x-intercept and y-intercept of y = 2x -2
# Slope is (m = y2-y1/x2-x1). Find the slope and Euclidean distance between point (2, 2) and point (6,10)
# Compare the slopes in tasks 8 and 9.

# %%
x1 = 2
y1 = 2
x2 = 6
y2 = 10

m = ( y2 - y1) / (x2 - x1) 
print(m)
# Out:
# 2.0

# %% [markdown]
# Calculate the value of y (y = x^2 + 6x + 9). Try to use different x values and figure out at what x value y is going to be 0.

# %%
x= int(input("digite number : "))
y = (x * x) + (6 * x) + 9
print(y)
# Out:
# 36

# %% [markdown]
# Find the length of 'python' and 'dragon' and make a falsy comparison statement.

# %%
word_a = 'python'
word_b  = 'dragon'
print(len(word_a) > len(word_b))
# Out:
# False

# %% [markdown]
# Use and operator to check if 'on' is found in both 'python' and 'dragon'

# %%
word_a = 'python'
word_b  = 'dragon'
print("on" in word_a and "on" in word_b )
# Out:
# False

# %% [markdown]
# I hope this course is not full of jargon. Use in operator to check if jargon is in the sentence.

# %%
sentence = "I hope this course is not full of jargon"
print("jargon" in sentence)
# Out:
# True

# %% [markdown]
# Find the length of the text python and convert the value to float and convert it to string

# %%
word = 'python'
length = float(len(word))
print(length)
print(type(length))
length_str = str(length)
print(length_str)
print(type(length_str))
# Out:
# 6.0
# <class 'float'>
# 6.0
# <class 'str'>

# %% [markdown]
# Writ a script that prompts the user to enter hours and rate per hour. Calculate pay of the person?
# Enter hours: 40
# Enter rate per hour: 28
# Your weekly earning is 1120

# %%
hours = int(input("Enter hours: "))
rate = int(input("Enter rate per hour: "))
print(f" Your weekly earning is {hours * rate }")
# Out:
#  Your weekly earning is 1120

# %% [markdown]
# Write a script that prompts the user to enter number of years. Calculate the number of seconds a person can live. Assume a person can live hundred years

# %%
years = int(input("Enter number of years you have lived: "))
print(f"You have lived for {31536000 * years} seconds.")
# Out:
# You have lived for 3153600000 seconds.

# %% [markdown]
# Write a Python script that displays the following table:
#
# ```py
# 1 1 1 1 1
# 2 1 2 4 8
# 3 1 3 9 27
# 4 1 4 16 64
# 5 1 5 25 125
# ```

# %%
n = 1
print(n, 1, n, n*n, n*n*n)

n = 2
print(n, 1, n, n*n, n*n*n)

n = 3
print(n, 1, n, n*n, n*n*n)

n = 4
print(n, 1, n, n*n, n*n*n)

n = 5
print(n, 1, n, n*n, n*n*n)
# Out:
# 1 1 1 1 1
# 2 1 2 4 8
# 3 1 3 9 27
# 4 1 4 16 64
# 5 1 5 25 125
